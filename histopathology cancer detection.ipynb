# %% [markdown]
# **Summary**
#
# In this project, I created a Convolutional Neural Network model to identify metastatic cancer in small image patches taken from larger digital pathology scans. The model achieved great scores for accuracy (90%), precision (90%), recall (90%), F1-score (90%) and Auc score (96%).

# %% [markdown]
# **The dataset**
#
# The data for this competition is a slightly modified version of the PatchCamelyon (PCam) benchmark dataset (the original PCam dataset contains duplicate images due to its probabilistic sampling, however, the version presented on Kaggle does not contain duplicates).
# [PCam] packs the clinically-relevant task of metastasis detection into a straight-forward binary image classification task, akin to CIFAR-10 and MNIST. Models can easily be trained on a single GPU in a couple hours, and achieve competitive scores in the Camelyon16 tasks of tumor detection and whole-slide image diagnosis. Furthermore, the balance between task-difficulty and tractability makes it a prime suspect for fundamental machine learning research on topics as active learning, model uncertainty, and explainability.

# %% [markdown]
# **Importing libraries**

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input/histopathologic-cancer-detectiont'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from numpy.random import seed
seed(101)

import pandas as pd
import numpy as np


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

import os
import cv2

from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import itertools
import shutil
import matplotlib.pyplot as plt
# %matplotlib inline
tf.random.set_seed(101)

# %% [markdown]
# **Setting prerequisites**

# %%
img_size=96
img_ch=3
sample_size=50000

# %% [markdown]
# **Exploring the directory**

# %%
os.listdir('../input/histopathologic-cancer-detection')
# Out:
# ['sample_submission.csv', 'train_labels.csv', 'test', 'train']

# %% [markdown]
# **Data exploration**

# %%
print(len(os.listdir('../input/histopathologic-cancer-detection/train')))
print(len(os.listdir('../input/histopathologic-cancer-detection/test')))
# Out:
# 220025
# 57458

# %%
df_data = pd.read_csv('../input/histopathologic-cancer-detection/train_labels.csv')

# removing this image because it caused a training error previously
df_data[df_data['id'] != 'dd6dfed324f9fcb6f93f46f32fc800f2ec196be2']

# removing this image because it's black
df_data[df_data['id'] != '9369c7278ec8bcc6c880d99194de09fc2bd4efbe']

print(df_data.shape)
# Out:
# (220025, 2)

# %%
df_data['label'].value_counts()
# Out:
# 0    130908
# 1     89117
# Name: label, dtype: int64

# %%
labels_count = df_data.label.value_counts()

# %matplotlib inline
plt.pie(labels_count, labels=['No Cancer', 'Cancer'], startangle=180, 
        autopct='%1.1f', colors=['green','red'], shadow=True)
plt.figure(figsize=(15,15))
plt.show()

# %% [markdown]
# **Create the Train and Validation Sets**

# %%
df_0=df_data[df_data['label']==0].sample(sample_size,random_state=101)
df_1=df_data[df_data['label']==1].sample(sample_size,random_state=101)

# concat the dataframes
df_data = pd.concat([df_0, df_1], axis=0).reset_index(drop=True)
# shuffle
df_data = shuffle(df_data)

df_data['label'].value_counts()
# Out:
# 1    50000
# 0    50000
# Name: label, dtype: int64

# %% [markdown]
# Data splitting

# %%
y = df_data['label']

df_train, df_val = train_test_split(df_data, test_size=0.10, random_state=101, stratify=y)

print(df_train.shape)
print(df_val.shape)
# Out:
# (90000, 2)
# (10000, 2)

# %% [markdown]
# **Creating a new directory for the ImageDataGenerator**
#
# Let's create 2 folders inside 'base_dir':
# 1.train_dir: it contains:
#     # healthy_tissue
#     # tumor_tissue
#
# 2.val_dir: it contains:
#     # healthy_tissue
#     # tumor_tissue

# %%
base_dir='base_dir'
os.mkdir(base_dir)


# create a path to 'base_dir' to which we will join the names of the new folders
# train_dir
train_dir = os.path.join(base_dir, 'train_dir')
os.mkdir(train_dir)

# val_dir
val_dir = os.path.join(base_dir, 'val_dir')
os.mkdir(val_dir)


# [CREATE FOLDERS INSIDE THE TRAIN AND VALIDATION FOLDERS]
# Inside each folder we create seperate folders for each class

# create new folders inside train_dir
train_healthy_tissue_dir = os.path.join(train_dir, 'healthy_tissue')
os.mkdir(train_healthy_tissue_dir)
train_tumor_tissue_dir = os.path.join(train_dir, 'tumor_tissue')
os.mkdir(train_tumor_tissue_dir)


# create new folders inside val_dir
test_healthy_tissue_dir = os.path.join(val_dir, 'healthy_tissue')
os.mkdir(test_healthy_tissue_dir)
test_tumor_tissue_dir = os.path.join(val_dir, 'tumor_tissue')
os.mkdir(test_tumor_tissue_dir)

# %%
# check that the folders have been created
os.listdir('base_dir/train_dir')
# Out:
# ['healthy_tissue', 'tumor_tissue']

# %%
# Set the id as the index in df_data
df_data.set_index('id', inplace=True)

# %%
# Get a list of train and val images
train_list = list(df_train['id'])
val_list = list(df_val['id'])

# %%
# Transfer the train images

for image in train_list:
    
    # the id in the csv file does not have the .tif extension therefore we add it here
    fname = image + '.tif'
    # get the label for a certain image
    target = df_data.loc[image,'label']
    
    # these must match the folder names
    if target == 0:
        label = 'healthy_tissue'
    if target == 1:
        label = 'tumor_tissue'
    
    # source path to image
    src = os.path.join('../input/histopathologic-cancer-detection/train', fname)
    # destination path to image
    dst = os.path.join(train_dir, label, fname)
    # copy the image from the source to the destination
    shutil.copyfile(src, dst)


# Transfer the val images

for image in val_list:
    
    # the id in the csv file does not have the .tif extension therefore we add it here
    fname = image + '.tif'
    # get the label for a certain image
    target = df_data.loc[image,'label']
    
    # these must match the folder names
    if target == 0:
        label = 'healthy_tissue'
    if target == 1:
        label = 'tumor_tissue'
    

    # source path to image
    src = os.path.join('../input/histopathologic-cancer-detection/train', fname)
    # destination path to image
    dst = os.path.join(val_dir, label, fname)
    # copy the image from the source to the destination
    shutil.copyfile(src, dst)

# %%
# check how many train images we have in each folder

print(len(os.listdir('base_dir/train_dir/healthy_tissue')))
print(len(os.listdir('base_dir/train_dir/tumor_tissue')))
# Out:
# 45000
# 45000

# %%
# check how many val images we have in each folder

print(len(os.listdir('base_dir/val_dir/healthy_tissue')))
print(len(os.listdir('base_dir/val_dir/tumor_tissue')))
# Out:
# 5000
# 5000

# %% [markdown]
# **Data visualization**

# %%
#training
train_tumor_names = os.listdir(train_tumor_tissue_dir)
print(train_tumor_names[:5])
train_healthy_names = os.listdir(train_healthy_tissue_dir)
print(train_healthy_names[:5])
#test
test_tumor_names = os.listdir(test_tumor_tissue_dir)
print(test_tumor_names[:5])
test_healthy_names = os.listdir(test_healthy_tissue_dir)
print(test_healthy_names[:5])
# Out:
# ['0e5c9c1684561f2e60737daab52a6763d93578a4.tif', 'f62d38d7e05782fdfc6ec653ea70647a257c7bb5.tif', '856877c3dfe20cbdf391235814506666755815b5.tif', '394f7bb081715c7180eff8080d001ec7c61e8a57.tif', '2727106ed8d3b2fc842243b91927c00f4f8c6e30.tif']
# ['8989c66b4eb940cee9ad8731a2009adf92f6c467.tif', '77ae1e3593b1d8508770b50c0f32dcce6af5f46d.tif', 'fae5c39e13834d9402ec6599dc2879cbc794cbca.tif', '2b13fee9ba0306a2ebb5b3199c0fdb5932a4359f.tif', '48582b1a5042a7f79903ff76d399783e72bdfbe3.tif']
# ['33615d7a36b12a8af8895691b845c7070634c442.tif', 'd0c1751e27991be18ef9bfa4d3172ab800fca6e3.tif', '8ea4a7bf3434b1ac690138ff85bf8a813f049f0d.tif', '092ba1bd3bda9845729441696dce5ecc5729dad3.tif', 'f4463a2895c637d1fd53541bc3ac821d509d631c.tif']
# ['56cb42650500d4db513e9cd86d6681bc42a8f82f.tif', 'ec17e788f2b9cac3462bd67e466eb341d120e7a9.tif', 'e9ea49ed1cdd446dc88bb377e6e757edd1eb6239.tif', 'f113fd9e9b63c317d79db649f1714133c5218fa1.tif', '6ec5eb0044b5081220c45cb55e005a13592143a7.tif']

# %%
#get the filenames from the healthy and tumor dir of the train dataset
healthy_pic =[os.path.join(train_healthy_tissue_dir, filename) for filename in train_healthy_names[0:8]]
tumor_pic =[os.path.join(train_tumor_tissue_dir, filename) for filename in train_tumor_names[0:8]]

# %%
import matplotlib.pyplot as plt
# plot a grid of 8 images (4 images of each class)
import matplotlib.image as mpimg
#set the number of columns and rows
rows = 4
cols = 2
#set the figure size
fig = plt.gcf()
fig.set_size_inches(15,15)
#merge the covid and normal list
merged_list = healthy_pic+tumor_pic
for i , img_path in enumerate(merged_list):
  data= img_path.split('/', 2)[2] # <----maybe 2,2
  sp = plt.subplot(rows, cols, i + 1)
  sp.axis('Off')
  img = mpimg.imread(img_path)
  sp.set_title(data, fontsize=11)
  plt.imshow(img,cmap='gray')

  plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-59d463545db7> in <module>
#      12 for i , img_path in enumerate(merged_list):
#      13   data= img_path.split('/', 2)[2] # <----maybe 2,2
# ---> 14   sp = plt.subplot(rows, cols, i + 1)
#      15   sp.axis('Off')
#      16   img = mpimg.imread(img_path)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
#    1404         return self._add_axes_internal(key, ax)
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      37
#      38         self.figure = fig
# ---> 39         self._subplotspec = SubplotSpec._from_subplot_args(fig, args)
#      40         self.update_params()
#      41         # _axes_class is set in the subplot_class_factory
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     688                 if num < 1 or num > rows*cols:
#     689                     raise ValueError(
# --> 690                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     691                 return gs[num - 1]   # -1 due to MATLAB indexing.
#     692         else:
#
# ValueError: num must be 1 <= num <= 8, not 9

# %% [markdown]
# **Data Augmentation**
#
# The amount of data gathered was very low and could cause the models to under-fit. Hence, we would use a brilliant technique of Data Augmentation to increase the amount of data. This technique relies on rotations, flips, change in exposure, etc to create similar images. Using this technique we can increase the size of data by a high factor. The output image of the cropping stage is given as input to ImageDataGenerator which is a function in keras.preprocessing.image library. This function takes multiple arguments that decide how Augmentation takes place.

# %%
# Set up the generators
train_path = 'base_dir/train_dir'
valid_path = 'base_dir/val_dir'
test_path = '../input/histopathologic-cancer-detection/test'

num_train_samples = len(df_train)
num_val_samples = len(df_val)
train_batch_size = 10
val_batch_size = 10


train_steps = np.ceil(num_train_samples / train_batch_size)
val_steps = np.ceil(num_val_samples / val_batch_size)
datagen = ImageDataGenerator(rescale=1.0/255)

train_gen = datagen.flow_from_directory(train_path,
                                        target_size=(img_size,img_size),
                                        batch_size=train_batch_size,
                                        class_mode='categorical')

val_gen = datagen.flow_from_directory(valid_path,
                                        target_size=(img_size,img_size),
                                        batch_size=val_batch_size,
                                        class_mode='categorical')

# Note: shuffle=False causes the test dataset to not be shuffled
test_gen = datagen.flow_from_directory(valid_path,
                                        target_size=(img_size,img_size),
                                        batch_size=1,
                                        class_mode='categorical',
                                        shuffle=False)
# Out:
# Found 90000 images belonging to 2 classes.
# Found 10000 images belonging to 2 classes.
# Found 10000 images belonging to 2 classes.

# %%
from tensorflow.keras.preprocessing import image
sample_x,sample_y = next(train_gen)
plt.figure(figsize=(12,9))
for i in range(6):
    plt.subplot(2,3,i+1)
    sample = image.array_to_img(sample_x[i])
    plt.xlabel(np.argmax(sample_y[i]))
    plt.imshow(sample)
plt.show()

# %%
#get the class indices
train_gen.class_indices
# Out:
# {'healthy_tissue': 0, 'tumor_tissue': 1}

# %%
#get the image shape
train_gen.image_shape
# Out:
# (96, 96, 3)

# %% [markdown]
# **Model Building & Training**
#
# So until now we have cleaned, pre-processed, augmented, pickled the data and now we are ready to feed it to a ‘Neural Network’ and see how it performs. We will try to perform image classification task by using a CNN model.

# %% [markdown]
# **CNN model**
#
# I used a great CNN architecture from https://www.kaggle.com/homayoonkhadivi/medical-diagnosis-histopathologic-cancer-cnn. Moreover I added a further Dense layer (Dense,10), I increased the dropout value at 0.5, and I increased the number of epochs from 20 to 50. To achieve a better understanding of the model, I considered as metric not only accuracy, but I added Precision, Recall, Auc score and F1 score for each epoch.

# %%
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
import tensorflow.keras.backend as K

# %%
kernel_size = (3,3)
pool_size= (2,2)
first_filters = 32
second_filters = 64
third_filters = 128

dropout_conv = 0.5
dropout_dense = 0.5


model = Sequential()
model.add(Conv2D(first_filters, kernel_size, activation = 'relu', input_shape = (96, 96, 3)))
model.add(Conv2D(first_filters, kernel_size, activation = 'relu'))
model.add(Conv2D(first_filters, kernel_size, activation = 'relu'))
model.add(MaxPooling2D(pool_size = pool_size)) 
model.add(Dropout(dropout_conv))

model.add(Conv2D(second_filters, kernel_size, activation ='relu'))
model.add(Conv2D(second_filters, kernel_size, activation ='relu'))
model.add(Conv2D(second_filters, kernel_size, activation ='relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(Conv2D(third_filters, kernel_size, activation ='relu'))
model.add(MaxPooling2D(pool_size = pool_size))
model.add(Dropout(dropout_conv))

model.add(Flatten())
model.add(Dense(256, activation = "relu"))
model.add(Dropout(dropout_dense))
model.add(Dense(10, activation = "relu"))
model.add(Dropout(dropout_dense))
model.add(Dense(2, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_92 (Conv2D)           (None, 94, 94, 32)        896
# _________________________________________________________________
# conv2d_93 (Conv2D)           (None, 92, 92, 32)        9248
# _________________________________________________________________
# conv2d_94 (Conv2D)           (None, 90, 90, 32)        9248
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 45, 45, 32)        0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_95 (Conv2D)           (None, 43, 43, 64)        18496
# _________________________________________________________________
# conv2d_96 (Conv2D)           (None, 41, 41, 64)        36928
# _________________________________________________________________
# conv2d_97 (Conv2D)           (None, 39, 39, 64)        36928
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 19, 19, 64)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 19, 19, 64)        0
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 17, 17, 128)       73856
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 15, 15, 128)       147584
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 13, 13, 128)       147584
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               1179904
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2570
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 10)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 1,663,264
# Trainable params: 1,663,264
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Compile & Train the CNN Model**
#
# To amplify our understanding of the model and its performance, we assess different metrics: loss function, accuracy, precision, recall anmd F1 scores.

# %%
def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

# %%
import tensorflow as tf
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# **Let's define the metrics**

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
        f1_score,
]

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 5) # when i run it for 50 epochs

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

# %%
model.compile(Adam(lr=0.0001),loss='binary_crossentropy',metrics=METRICS)

# %% [markdown]
# **Training the model**

# %%
filepath = "CNN-model"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, 
                             save_best_only=True, mode='max')

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.5, patience=2, 
                                   verbose=1, mode='max', min_lr=0.00001)
                              
                              
callbacks_list = [checkpoint, reduce_lr]

history = model.fit(train_gen, steps_per_epoch=train_steps, 
                    validation_data=val_gen,
                    validation_steps=val_steps,
                    epochs=50, verbose=1,
                    callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 9000/9000 [==============================] - 168s 18ms/step - loss: 0.4406 - accuracy: 0.8113 - precision: 0.8113 - recall: 0.8113 - auc: 0.8866 - f1_score: 0.8113 - val_loss: 0.4425 - val_accuracy: 0.8001 - val_precision: 0.8001 - val_recall: 0.8001 - val_auc: 0.8842 - val_f1_score: 0.8001
# Epoch 2/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.3975 - accuracy: 0.8336 - precision: 0.8336 - recall: 0.8336 - auc: 0.9072 - f1_score: 0.8336 - val_loss: 0.4212 - val_accuracy: 0.8175 - val_precision: 0.8175 - val_recall: 0.8175 - val_auc: 0.8977 - val_f1_score: 0.8175
# Epoch 3/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.3751 - accuracy: 0.8406 - precision: 0.8406 - recall: 0.8406 - auc: 0.9171 - f1_score: 0.8405 - val_loss: 0.4090 - val_accuracy: 0.8266 - val_precision: 0.8266 - val_recall: 0.8266 - val_auc: 0.9065 - val_f1_score: 0.8266
# Epoch 4/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.3515 - accuracy: 0.8512 - precision: 0.8512 - recall: 0.8512 - auc: 0.9264 - f1_score: 0.8512 - val_loss: 0.4582 - val_accuracy: 0.8169 - val_precision: 0.8169 - val_recall: 0.8169 - val_auc: 0.8916 - val_f1_score: 0.8169
# Epoch 5/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.3406 - accuracy: 0.8586 - precision: 0.8586 - recall: 0.8586 - auc: 0.9312 - f1_score: 0.8586 - val_loss: 0.4998 - val_accuracy: 0.8038 - val_precision: 0.8038 - val_recall: 0.8038 - val_auc: 0.8833 - val_f1_score: 0.8038
# Epoch 6/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.3277 - accuracy: 0.8636 - precision: 0.8636 - recall: 0.8636 - auc: 0.9361 - f1_score: 0.8636 - val_loss: 0.3726 - val_accuracy: 0.8372 - val_precision: 0.8372 - val_recall: 0.8372 - val_auc: 0.9178 - val_f1_score: 0.8372
# Epoch 7/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.3233 - accuracy: 0.8685 - precision: 0.8685 - recall: 0.8685 - auc: 0.9383 - f1_score: 0.8685 - val_loss: 0.5836 - val_accuracy: 0.7894 - val_precision: 0.7894 - val_recall: 0.7894 - val_auc: 0.8662 - val_f1_score: 0.7894
# Epoch 8/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.3145 - accuracy: 0.8703 - precision: 0.8703 - recall: 0.8703 - auc: 0.9410 - f1_score: 0.8703 - val_loss: 0.4715 - val_accuracy: 0.8244 - val_precision: 0.8244 - val_recall: 0.8244 - val_auc: 0.8968 - val_f1_score: 0.8244
# Epoch 9/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.3109 - accuracy: 0.8716 - precision: 0.8716 - recall: 0.8716 - auc: 0.9424 - f1_score: 0.8716 - val_loss: 0.4207 - val_accuracy: 0.8420 - val_precision: 0.8420 - val_recall: 0.8420 - val_auc: 0.9111 - val_f1_score: 0.8420
# Epoch 10/50
# 9000/9000 [==============================] - 164s 18ms/step - loss: 0.2998 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9461 - f1_score: 0.8779 - val_loss: 0.4235 - val_accuracy: 0.8467 - val_precision: 0.8467 - val_recall: 0.8467 - val_auc: 0.9085 - val_f1_score: 0.8467
# Epoch 11/50
# 9000/9000 [==============================] - 164s 18ms/step - loss: 0.2967 - accuracy: 0.8789 - precision: 0.8789 - recall: 0.8789 - auc: 0.9470 - f1_score: 0.8789 - val_loss: 0.4740 - val_accuracy: 0.8067 - val_precision: 0.8067 - val_recall: 0.8067 - val_auc: 0.8880 - val_f1_score: 0.8067
# Epoch 12/50
# 9000/9000 [==============================] - 164s 18ms/step - loss: 0.2900 - accuracy: 0.8822 - precision: 0.8822 - recall: 0.8822 - auc: 0.9495 - f1_score: 0.8821 - val_loss: 0.4692 - val_accuracy: 0.8253 - val_precision: 0.8253 - val_recall: 0.8253 - val_auc: 0.8995 - val_f1_score: 0.8253
# Epoch 13/50
# 9000/9000 [==============================] - 164s 18ms/step - loss: 0.2868 - accuracy: 0.8839 - precision: 0.8839 - recall: 0.8839 - auc: 0.9504 - f1_score: 0.8839 - val_loss: 0.3347 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.9288 - val_f1_score: 0.8571
# Epoch 14/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2828 - accuracy: 0.8880 - precision: 0.8880 - recall: 0.8880 - auc: 0.9516 - f1_score: 0.8880 - val_loss: 0.2970 - val_accuracy: 0.8840 - val_precision: 0.8840 - val_recall: 0.8840 - val_auc: 0.9458 - val_f1_score: 0.8840
# Epoch 15/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2772 - accuracy: 0.8889 - precision: 0.8889 - recall: 0.8889 - auc: 0.9532 - f1_score: 0.8889 - val_loss: 0.4748 - val_accuracy: 0.8305 - val_precision: 0.8305 - val_recall: 0.8305 - val_auc: 0.8931 - val_f1_score: 0.8305
# Epoch 16/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2758 - accuracy: 0.8885 - precision: 0.8885 - recall: 0.8885 - auc: 0.9539 - f1_score: 0.8885 - val_loss: 0.2640 - val_accuracy: 0.8951 - val_precision: 0.8951 - val_recall: 0.8951 - val_auc: 0.9549 - val_f1_score: 0.8951
# Epoch 17/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2710 - accuracy: 0.8944 - precision: 0.8944 - recall: 0.8944 - auc: 0.9552 - f1_score: 0.8944 - val_loss: 0.3628 - val_accuracy: 0.8628 - val_precision: 0.8628 - val_recall: 0.8628 - val_auc: 0.9266 - val_f1_score: 0.8628
# Epoch 18/50
# 9000/9000 [==============================] - 164s 18ms/step - loss: 0.2704 - accuracy: 0.8914 - precision: 0.8914 - recall: 0.8914 - auc: 0.9553 - f1_score: 0.8914 - val_loss: 0.4096 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.9059 - val_f1_score: 0.8308
# Epoch 19/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2674 - accuracy: 0.8941 - precision: 0.8941 - recall: 0.8941 - auc: 0.9567 - f1_score: 0.8941 - val_loss: 0.2365 - val_accuracy: 0.9009 - val_precision: 0.9009 - val_recall: 0.9009 - val_auc: 0.9628 - val_f1_score: 0.9009
# Epoch 20/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2640 - accuracy: 0.8949 - precision: 0.8949 - recall: 0.8949 - auc: 0.9573 - f1_score: 0.8949 - val_loss: 0.4322 - val_accuracy: 0.8484 - val_precision: 0.8484 - val_recall: 0.8484 - val_auc: 0.9151 - val_f1_score: 0.8484
# Epoch 21/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2580 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9594 - f1_score: 0.8979 - val_loss: 0.3197 - val_accuracy: 0.8623 - val_precision: 0.8623 - val_recall: 0.8623 - val_auc: 0.9335 - val_f1_score: 0.8623
# Epoch 22/50
# 9000/9000 [==============================] - 163s 18ms/step - loss: 0.2603 - accuracy: 0.8980 - precision: 0.8980 - recall: 0.8980 - auc: 0.9593 - f1_score: 0.8980 - val_loss: 0.3025 - val_accuracy: 0.8737 - val_precision: 0.8737 - val_recall: 0.8737 - val_auc: 0.9412 - val_f1_score: 0.8737
# Epoch 23/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2553 - accuracy: 0.8987 - precision: 0.8987 - recall: 0.8987 - auc: 0.9602 - f1_score: 0.8986 - val_loss: 0.3656 - val_accuracy: 0.8509 - val_precision: 0.8509 - val_recall: 0.8509 - val_auc: 0.9239 - val_f1_score: 0.8509
# Epoch 24/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2539 - accuracy: 0.9008 - precision: 0.9008 - recall: 0.9008 - auc: 0.9603 - f1_score: 0.9008 - val_loss: 0.3058 - val_accuracy: 0.8756 - val_precision: 0.8756 - val_recall: 0.8756 - val_auc: 0.9412 - val_f1_score: 0.8756
# Epoch 25/50
# 9000/9000 [==============================] - 167s 19ms/step - loss: 0.2525 - accuracy: 0.9008 - precision: 0.9008 - recall: 0.9008 - auc: 0.9608 - f1_score: 0.9008 - val_loss: 0.2550 - val_accuracy: 0.8969 - val_precision: 0.8969 - val_recall: 0.8969 - val_auc: 0.9577 - val_f1_score: 0.8969
# Epoch 26/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2530 - accuracy: 0.9011 - precision: 0.9011 - recall: 0.9011 - auc: 0.9608 - f1_score: 0.9011 - val_loss: 0.3287 - val_accuracy: 0.8809 - val_precision: 0.8809 - val_recall: 0.8809 - val_auc: 0.9406 - val_f1_score: 0.8809
# Epoch 27/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2595 - accuracy: 0.8977 - precision: 0.8977 - recall: 0.8977 - auc: 0.9591 - f1_score: 0.8977 - val_loss: 0.3064 - val_accuracy: 0.8786 - val_precision: 0.8786 - val_recall: 0.8786 - val_auc: 0.9438 - val_f1_score: 0.8786
# Epoch 28/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2494 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9615 - f1_score: 0.9023 - val_loss: 0.2694 - val_accuracy: 0.8917 - val_precision: 0.8917 - val_recall: 0.8917 - val_auc: 0.9523 - val_f1_score: 0.8917
# Epoch 29/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2422 - accuracy: 0.9060 - precision: 0.9060 - recall: 0.9060 - auc: 0.9638 - f1_score: 0.9060 - val_loss: 0.2889 - val_accuracy: 0.8850 - val_precision: 0.8850 - val_recall: 0.8850 - val_auc: 0.9484 - val_f1_score: 0.8850
# Epoch 30/50
# 9000/9000 [==============================] - 167s 19ms/step - loss: 0.2442 - accuracy: 0.9047 - precision: 0.9047 - recall: 0.9047 - auc: 0.9630 - f1_score: 0.9047 - val_loss: 0.3167 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9404 - val_f1_score: 0.8778
# Epoch 31/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2484 - accuracy: 0.9025 - precision: 0.9025 - recall: 0.9025 - auc: 0.9619 - f1_score: 0.9024 - val_loss: 0.2413 - val_accuracy: 0.9092 - val_precision: 0.9092 - val_recall: 0.9092 - val_auc: 0.9616 - val_f1_score: 0.9092
# Epoch 32/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2409 - accuracy: 0.9057 - precision: 0.9057 - recall: 0.9057 - auc: 0.9637 - f1_score: 0.9057 - val_loss: 0.2813 - val_accuracy: 0.8851 - val_precision: 0.8851 - val_recall: 0.8851 - val_auc: 0.9485 - val_f1_score: 0.8851
# Epoch 33/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2437 - accuracy: 0.9062 - precision: 0.9062 - recall: 0.9062 - auc: 0.9633 - f1_score: 0.9062 - val_loss: 0.3605 - val_accuracy: 0.8585 - val_precision: 0.8585 - val_recall: 0.8585 - val_auc: 0.9272 - val_f1_score: 0.8585
# Epoch 34/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2391 - accuracy: 0.9055 - precision: 0.9055 - recall: 0.9055 - auc: 0.9642 - f1_score: 0.9055 - val_loss: 0.2177 - val_accuracy: 0.9137 - val_precision: 0.9137 - val_recall: 0.9137 - val_auc: 0.9662 - val_f1_score: 0.9137
# Epoch 35/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2365 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9651 - f1_score: 0.9063 - val_loss: 0.2328 - val_accuracy: 0.9121 - val_precision: 0.9121 - val_recall: 0.9121 - val_auc: 0.9665 - val_f1_score: 0.9121
# Epoch 36/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2361 - accuracy: 0.9095 - precision: 0.9095 - recall: 0.9095 - auc: 0.9656 - f1_score: 0.9095 - val_loss: 0.3135 - val_accuracy: 0.8691 - val_precision: 0.8691 - val_recall: 0.8691 - val_auc: 0.9455 - val_f1_score: 0.8691
# Epoch 37/50
# 9000/9000 [==============================] - 164s 18ms/step - loss: 0.2338 - accuracy: 0.9098 - precision: 0.9098 - recall: 0.9098 - auc: 0.9655 - f1_score: 0.9097 - val_loss: 0.2740 - val_accuracy: 0.8921 - val_precision: 0.8921 - val_recall: 0.8921 - val_auc: 0.9560 - val_f1_score: 0.8921
# Epoch 38/50
# 9000/9000 [==============================] - 164s 18ms/step - loss: 0.2336 - accuracy: 0.9091 - precision: 0.9091 - recall: 0.9091 - auc: 0.9664 - f1_score: 0.9091 - val_loss: 0.2836 - val_accuracy: 0.8925 - val_precision: 0.8925 - val_recall: 0.8925 - val_auc: 0.9499 - val_f1_score: 0.8925
# Epoch 39/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2315 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9663 - f1_score: 0.9094 - val_loss: 0.3078 - val_accuracy: 0.8837 - val_precision: 0.8837 - val_recall: 0.8837 - val_auc: 0.9440 - val_f1_score: 0.8837
# Epoch 40/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2291 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9673 - f1_score: 0.9094 - val_loss: 0.2166 - val_accuracy: 0.9148 - val_precision: 0.9148 - val_recall: 0.9148 - val_auc: 0.9669 - val_f1_score: 0.9148
# Epoch 41/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2383 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9647 - f1_score: 0.9041 - val_loss: 0.2281 - val_accuracy: 0.9063 - val_precision: 0.9063 - val_recall: 0.9063 - val_auc: 0.9646 - val_f1_score: 0.9063
# Epoch 42/50
# 9000/9000 [==============================] - 167s 19ms/step - loss: 0.2279 - accuracy: 0.9088 - precision: 0.9088 - recall: 0.9088 - auc: 0.9666 - f1_score: 0.9088 - val_loss: 0.2249 - val_accuracy: 0.9091 - val_precision: 0.9091 - val_recall: 0.9091 - val_auc: 0.9651 - val_f1_score: 0.9091
# Epoch 43/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2242 - accuracy: 0.9110 - precision: 0.9110 - recall: 0.9110 - auc: 0.9679 - f1_score: 0.9110 - val_loss: 0.2365 - val_accuracy: 0.8984 - val_precision: 0.8984 - val_recall: 0.8984 - val_auc: 0.9637 - val_f1_score: 0.8984
# Epoch 44/50
# 9000/9000 [==============================] - 165s 18ms/step - loss: 0.2269 - accuracy: 0.9109 - precision: 0.9109 - recall: 0.9109 - auc: 0.9680 - f1_score: 0.9109 - val_loss: 0.2345 - val_accuracy: 0.9044 - val_precision: 0.9044 - val_recall: 0.9044 - val_auc: 0.9650 - val_f1_score: 0.9044
# Epoch 45/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2272 - accuracy: 0.9122 - precision: 0.9122 - recall: 0.9122 - auc: 0.9672 - f1_score: 0.9122 - val_loss: 0.2281 - val_accuracy: 0.9092 - val_precision: 0.9092 - val_recall: 0.9092 - val_auc: 0.9653 - val_f1_score: 0.9092
# Epoch 46/50
# 9000/9000 [==============================] - 166s 18ms/step - loss: 0.2306 - accuracy: 0.9083 - precision: 0.9083 - recall: 0.9083 - auc: 0.9663 - f1_score: 0.9083 - val_loss: 0.3172 - val_accuracy: 0.8762 - val_precision: 0.8762 - val_recall: 0.8762 - val_auc: 0.9412 - val_f1_score: 0.8762
# Epoch 47/50
# 9000/9000 [==============================] - 167s 19ms/step - loss: 0.2233 - accuracy: 0.9136 - precision: 0.9136 - recall: 0.9136 - auc: 0.9688 - f1_score: 0.9136 - val_loss: 0.2125 - val_accuracy: 0.9134 - val_precision: 0.9134 - val_recall: 0.9134 - val_auc: 0.9687 - val_f1_score: 0.9134
# Epoch 48/50
# 9000/9000 [==============================] - 167s 19ms/step - loss: 0.2190 - accuracy: 0.9151 - precision: 0.9151 - recall: 0.9151 - auc: 0.9698 - f1_score: 0.9151 - val_loss: 0.6877 - val_accuracy: 0.7332 - val_precision: 0.7332 - val_recall: 0.7332 - val_auc: 0.8088 - val_f1_score: 0.7332
# Epoch 49/50
# 9000/9000 [==============================] - 168s 19ms/step - loss: 0.2312 - accuracy: 0.9105 - precision: 0.9105 - recall: 0.9105 - auc: 0.9666 - f1_score: 0.9105 - val_loss: 0.2400 - val_accuracy: 0.9017 - val_precision: 0.9017 - val_recall: 0.9017 - val_auc: 0.9629 - val_f1_score: 0.9017
# Epoch 50/50
# 9000/9000 [==============================] - 167s 18ms/step - loss: 0.2261 - accuracy: 0.9118 - precision: 0.9118 - recall: 0.9118 - auc: 0.9681 - f1_score: 0.9118 - val_loss: 0.2402 - val_accuracy: 0.9098 - val_precision: 0.9098 - val_recall: 0.9098 - val_auc: 0.9655 - val_f1_score: 0.9098

# %% [markdown]
# **Model Performance Evaluation**

# %%
#get the keys of history object

history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'recall', 'auc', 'f1_score', 'val_loss', 'val_accuracy', 'val_precision', 'val_recall', 'val_auc', 'val_f1_score', 'lr'])

# %%
def Train_Val_Plot(acc,val_acc,loss,val_loss,auc,val_auc,precision,val_precision,f1,val_f1):
  fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
  fig.suptitle(" MODEL'S METRICS VISUALIZATION ")
  ax1.plot(range(1, len(acc) + 1), acc)
  ax1.plot(range(1, len(val_acc) + 1), val_acc)
  ax1.set_title('History of Accuracy')
  ax1.set_xlabel('Epochs')
  ax1.set_ylabel('Accuracy')
  ax1.legend(['training', 'validation'])
  ax2.plot(range(1, len(loss) + 1), loss)
  ax2.plot(range(1, len(val_loss) + 1), val_loss)
  ax2.set_title('History of Loss')
  ax2.set_xlabel('Epochs')
  ax2.set_ylabel('Loss')
  ax2.legend(['training', 'validation'])
    
  ax3.plot(range(1, len(auc) + 1), auc)
  ax3.plot(range(1, len(val_auc) + 1), val_auc)
  ax3.set_title('History of AUC')
  ax3.set_xlabel('Epochs')
  ax3.set_ylabel('AUC')
  ax3.legend(['training', 'validation'])

  ax4.plot(range(1, len(precision) + 1), precision)
  ax4.plot(range(1, len(val_precision) + 1), val_precision)
  ax4.set_title('History of Precision')
  ax4.set_xlabel('Epochs')
  ax4.set_ylabel('Precision')
  ax4.legend(['training', 'validation'])
    
  ax5.plot(range(1, len(f1) + 1), f1)
  ax5.plot(range(1, len(val_f1) + 1), val_f1)
  ax5.set_title('History of F1-score')
  ax5.set_xlabel('Epochs')
  ax5.set_ylabel('F1 score')
  ax5.legend(['training', 'validation'])


  plt.show()

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
                 history.history['loss'],history.history['val_loss'],
                 history.history['auc'],history.history['val_auc'],
                 history.history['precision'],history.history['val_precision'],
                 history.history['f1_score'],history.history['val_f1_score']
                 )

# %%
# Get the labels that are associated with each index
print(val_gen.class_indices)
# Out:
# {'healthy_tissue': 0, 'tumor_tissue': 1}

# %%
# get the metric names so we can use evaulate_generator
model.metrics_names
# Out:
# ['loss', 'accuracy', 'precision', 'recall', 'auc', 'f1_score']

# %%
scores = model.evaluate(test_gen)
# Out:
# 10000/10000 [==============================] - 66s 7ms/step - loss: 0.2402 - accuracy: 0.9098 - precision: 0.9098 - recall: 0.9098 - auc: 0.9655 - f1_score: 0.9098

# %%
print("CNN Accuracy = ", scores[1])
print("CNN Precision = ", scores[2])
print("CNN Recall = ", scores[3])
print("CNN AUC = ", scores[4])
print("CNN F1_score = ", scores[5])
# Out:
# CNN Accuracy =  0.9097999930381775
# CNN Precision =  0.9097999930381775
# CNN Recall =  0.9097999930381775
# CNN AUC =  0.9654750227928162
# CNN F1_score =  0.9097998738288879

# %% [markdown]
# As we can see, we achieved a good overall performance for all the metrics! So we can conclude that our CNN model could be a good piece of work in histopathology for classification tasks.
